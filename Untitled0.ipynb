# %%
import matplotlib.pyplot as plt

x_values = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June']
y_values = [100, 130, 80, 150, 140, 130]

plt.bar(x_values, y_values)
plt.plot()

plt.show()

# %%
text = input("文字を入力してください：")
lower_Text = text.lower()
print(lower_Text)
# Out:
# 文字を入力してください：ABCdefG
# abcdefg

# %%
import io
import requests
import PIL.Image

response = requests.get("https://www.python.jp/logo.png")
PIL.Image.open(io.BytesIO(response.content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=240x80 at 0x7FD5398D69D0>

# %%
import io
import requests
import PIL.Image

response = requests.get("https://www.python.jp/sampledata/Japanese_Squirrel_WUXGA.jpg")
PIL.Image.open(io.BytesIO(response.content))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
